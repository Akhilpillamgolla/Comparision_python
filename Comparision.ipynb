# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
'String' == 'string' # casing also must be same
# Out:
# False

# %%
'2' == 2 # string data is != int data
# Out:
# False

# %%
3 != 3  # not equal
# Out:
# False

# %%
1<2<3
# Out:
# True

# %%
1 < 2 > 3 # even first one is true the second one is no longer true.
# Out:
# False

# %% [markdown]
# AND

# %% [markdown]
# In and both conditions must be true.

# %%
1< 2 and  2< 3
# Out:
# True

# %%
1<2 and 3<2
# Out:
# False

# %% [markdown]
# OR

# %% [markdown]
# In or keyword 1 condition must be true.

# %%
100 == 1 or 2 == 2
# Out:
# True

# %%
500 == 500 or 20 ==20
# Out:
# True

# %% [markdown]
# NOT

# %% [markdown]
# Not keyword will give you revers of the output .

# %%
not 1 == 1
# Out:
# False

# %%
not 400 > 1000
# Out:
# True
